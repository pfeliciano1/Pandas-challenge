# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculate the total number of schools
total_schools = len(school_data_complete["school_name"].unique())
print(total_schools)
# Calculate the total number of students
total_students = school_data_complete["student_name"].count()
print(total_students)
# Calculate the total budget
total_budget = sum(school_data_complete["budget"].unique())
print(total_budget)
# Out:
# 15
# 39170
# 24649428

# %%
# Calculate the average math score
avg_math_score = school_data_complete["math_score"].mean()
print(avg_math_score)
# Calculate the average reading score
avg_reading_score = school_data_complete["reading_score"].mean()
print(avg_reading_score)
# Out:
# 78.98537145774827
# 81.87784018381414

# %%
# Calculate the percentage of students with a passing math score (70 or greater) 
percent_pass_math = (school_data_complete[school_data_complete["math_score"] >= 70].math_score.count()/total_students)*100
print(percent_pass_math)
# Calculate the percentage of students with a passing reading score (70 or greater)
percent_pass_reading = (school_data_complete[school_data_complete["reading_score"] >= 70].reading_score.count()/total_students)*100
print(percent_pass_reading)
# Calculate the percentage of students who passed math and reading (% Overall Passing)
percent_pass_overall = (school_data_complete[(school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)].student_name.count()/total_students)*100
print(percent_pass_overall)
# Out:
# 74.9808526933878
# 85.80546336482001
# 65.17232575950983

# %%
# Create a dataframe to hold the above results
# Optional: give the displayed data cleaner formatting
district_summary = [{"Total Schools": total_schools, "Total Students": f"{total_students:,}", 
                     "Total Budget": f"${total_budget:,.2f}", "Average Math Score": avg_math_score, 
                     "Average Reading Score": avg_reading_score, "% Passing Math": percent_pass_math, 
                     "% Passing Reading": percent_pass_reading, "% Overall Passing": percent_pass_overall}]
district_summary_df = pd.DataFrame(district_summary)
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Overview table that summarizes key metrics about each school
# Group by School Name
school_name = school_data_complete.groupby(["school_name"])
school_name.count()
# Out:
#                        Student ID  student_name  gender  grade  reading_score  \
# school_name
# Bailey High School           4976          4976    4976   4976           4976
# Cabrera High School          1858          1858    1858   1858           1858
# Figueroa High School         2949          2949    2949   2949           2949
# Ford High School             2739          2739    2739   2739           2739
# Griffin High School          1468          1468    1468   1468           1468
# Hernandez High School        4635          4635    4635   4635           4635
# Holden High School            427           427     427    427            427
# Huang High School            2917          2917    2917   2917           2917
# Johnson High School          4761          4761    4761   4761           4761
# Pena High School              962           962     962    962            962
# Rodriguez High School        3999          3999    3999   3999           3999
# ...

# %%
# Group by School Type
school_type = school_name["type"].unique()
school_type
# Out:
# school_name
# Bailey High School       [District]
# Cabrera High School       [Charter]
# Figueroa High School     [District]
# Ford High School         [District]
# Griffin High School       [Charter]
# Hernandez High School    [District]
# Holden High School        [Charter]
# Huang High School        [District]
# Johnson High School      [District]
# Pena High School          [Charter]
# Rodriguez High School    [District]
# Shelton High School       [Charter]
# Thomas High School        [Charter]
# Wilson High School        [Charter]
# Wright High School        [Charter]
# Name: type, dtype: object

# %%
# Group by Total Students
total_num_students = school_name["Student ID"].count()
print(total_num_students)
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
# Group by Total School Budget
total_school_budget = school_name["budget"].mean()
# school_data_complete.groupby(["school_name","budget"])
print(total_school_budget)
# Out:
# school_name
# Bailey High School       3124928
# Cabrera High School      1081356
# Figueroa High School     1884411
# Ford High School         1763916
# Griffin High School       917500
# Hernandez High School    3022020
# Holden High School        248087
# Huang High School        1910635
# Johnson High School      3094650
# Pena High School          585858
# Rodriguez High School    2547363
# Shelton High School      1056600
# Thomas High School       1043130
# Wilson High School       1319574
# Wright High School       1049400
# Name: budget, dtype: int64

# %%
# # Group by Per Student Budget
per_student_budget = total_school_budget/total_num_students
# school_name["budget"]/school_name["size"]
print(per_student_budget)
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# Group by Average Math Score
average_math_score = school_name["math_score"].mean()
print(average_math_score)
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
# Group by Average Reading Score
average_reading_score = school_name["reading_score"].mean()
print(average_reading_score)
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# Group by % Passing Math
percent_passing_math = school_data_complete.query("math_score >70")["School ID"].count()/ total_num_students
print(percent_passing_math)
# Out:
# school_name
# Bailey High School        5.698553
# Cabrera High School      15.261572
# Figueroa High School      9.615463
# Ford High School         10.352683
# Griffin High School      19.316076
# Hernandez High School     6.117799
# Holden High School       66.407494
# Huang High School         9.720946
# Johnson High School       5.955892
# Pena High School         29.476091
# Rodriguez High School     7.090773
# Shelton High School      16.102215
# Thomas High School       17.343119
# Wilson High School       12.420499
# Wright High School       15.753333
# Name: Student ID, dtype: float64

# %%
# Group by % Passing Reading
percent_passing_reading = school_data_complete.query("reading_score >70")["School ID"].count()/ total_num_students
print(percent_passing_reading)
# Out:
# school_name
# Bailey High School        6.531350
# Cabrera High School      17.491927
# Figueroa High School     11.020685
# Ford High School         11.865644
# Griffin High School      22.138965
# Hernandez High School     7.011866
# Holden High School       76.112412
# Huang High School        11.141584
# Johnson High School       6.826297
# Pena High School         33.783784
# Rodriguez High School     8.127032
# Shelton High School      18.455423
# Thomas High School       19.877676
# Wilson High School       14.235655
# Wright High School       18.055556
# Name: Student ID, dtype: float64

# %%
# Group by % Overall Passing
percent_passing_overall = (average_math_score + average_reading_score)/2
print(percent_passing_overall)
# Out:
# school_name
# Bailey High School       79.041198
# Cabrera High School      83.518837
# Figueroa High School     78.934893
# Ford High School         78.924425
# Griffin High School      83.584128
# Hernandez High School    79.112082
# Holden High School       83.809133
# Huang High School        78.906068
# Johnson High School      79.019429
# Pena High School         83.942308
# Rodriguez High School    78.793698
# Shelton High School      83.542589
# Thomas High School       83.633639
# Wilson High School       83.631844
# Wright High School       83.818611
# dtype: float64

# %%
# Create a dataframe to hold the above results
school_summary = pd.DataFrame({"School Type": school_type,
                               "Total Students": total_num_students,
                               "Total School Budget": total_school_budget, 
                               "Per Student Budget": per_student_budget,
                               "Average Math Score": average_math_score,
                               "Average Reading Score": average_reading_score,   
                               "% Passing Math": percent_passing_math,
                               "% Passing Reading": percent_passing_reading,
                               "% Overall Passing": percent_passing_overall          
                                                                        
})

school_summary = school_summary[["Total Students",
                                 "Total School Budget",
                                 "Per Student Budget",
                                 "Average Math Score",
                                 "Average Reading Score",
                                 "% Passing Math",   
                                 "% Passing Reading",                                             
                                 "% Overall Passing"]]

# Formatting the column values with df['cost'] = df['cost'].map('${:,.2f}'.format)
school_summary["Total School Budget"] = school_summary["Total School Budget"].map('${:,.2f}'.format)
school_summary["Per Student Budget"] = school_summary["Per Student Budget"].map('${:,.2f}'.format)
school_summary["Average Math Score"] = school_summary["Average Math Score"].map('{:,.2f}'.format)
school_summary["Average Reading Score"] = school_summary["Average Reading Score"].map('{:,.2f}'.format)
school_summary["% Passing Math"] = school_summary["% Passing Math"].map('{:,.2f}%'.format)
school_summary["% Passing Reading"] = school_summary["% Passing Reading"].map('{:,.2f}%'.format)
school_summary["% Overall Passing"] = school_summary["% Overall Passing"].map('{:,.2f}%'.format)
school_summary.head(15)
# Out:
#                        Total Students Total School Budget Per Student Budget  \
# school_name
# Bailey High School               4976       $3,124,928.00            $628.00
# Cabrera High School              1858       $1,081,356.00            $582.00
# Figueroa High School             2949       $1,884,411.00            $639.00
# Ford High School                 2739       $1,763,916.00            $644.00
# Griffin High School              1468         $917,500.00            $625.00
# Hernandez High School            4635       $3,022,020.00            $652.00
# Holden High School                427         $248,087.00            $581.00
# Huang High School                2917       $1,910,635.00            $655.00
# Johnson High School              4761       $3,094,650.00            $650.00
# Pena High School                  962         $585,858.00            $609.00
# Rodriguez High School            3999       $2,547,363.00            $637.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %%
top_schools = school_summary.sort_values(
    ["% Overall Passing"], ascending=False)
top_schools.head()
# Out:
#                     Total Students Total School Budget Per Student Budget  \
# school_name
# Pena High School               962         $585,858.00            $609.00
# Wright High School            1800       $1,049,400.00            $583.00
# Holden High School             427         $248,087.00            $581.00
# Thomas High School            1635       $1,043,130.00            $638.00
# Wilson High School            2283       $1,319,574.00            $578.00
#
#                    Average Math Score Average Reading Score % Passing Math  \
# school_name
# Pena High School                83.84                 84.04         29.48%
# Wright High School              83.68                 83.95         15.75%
# Holden High School              83.80                 83.81         66.41%
# Thomas High School              83.42                 83.85         17.34%
# Wilson High School              83.27                 83.99         12.42%
#
# ...

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_schools = school_summary.sort_values(
    ["% Overall Passing"], ascending=True)
bottom_schools.head()
# Out:
#                        Total Students Total School Budget Per Student Budget  \
# school_name
# Rodriguez High School            3999       $2,547,363.00            $637.00
# Huang High School                2917       $1,910,635.00            $655.00
# Ford High School                 2739       $1,763,916.00            $644.00
# Figueroa High School             2949       $1,884,411.00            $639.00
# Johnson High School              4761       $3,094,650.00            $650.00
#
#                       Average Math Score Average Reading Score % Passing Math  \
# school_name
# Rodriguez High School              76.84                 80.74          7.09%
# Huang High School                  76.63                 81.18          9.72%
# Ford High School                   77.10                 80.75         10.35%
# Figueroa High School               76.71                 81.16          9.62%
# Johnson High School                77.07                 80.97          5.96%
#
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Create a table that lists the average Math Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
# Create a pandas series for each grade. Hint: use a conditional statement.
grade_9 = school_data_complete.loc[school_data_complete["grade"] == "9th"]
grade_10 = school_data_complete.loc[school_data_complete["grade"] == "10th"]
grade_11 = school_data_complete.loc[school_data_complete["grade"] == "11th"]
grade_12 = school_data_complete.loc[school_data_complete["grade"] == "12th"]

# Group each series by school
schools_grade_9 = grade_9.groupby(["school_name"]).mean()
schools_grade_10 = grade_10.groupby(["school_name"]).mean()
schools_grade_11 = grade_11.groupby(["school_name"]).mean()
schools_grade_12 = grade_12.groupby(["school_name"]).mean()

# Combine the series into a dataframe
math_scores_by_grade = pd.DataFrame({"9th":schools_grade_9["math_score"],
                                     "10th":schools_grade_10["math_score"],
                                     "11th":schools_grade_11["math_score"],
                                     "12th":schools_grade_12["math_score"]})

# Optional: give the displayed data cleaner formatting
math_scores_by_grade["9th"] = math_scores_by_grade["9th"].map('{:,.2f}'.format)
math_scores_by_grade["10th"] = math_scores_by_grade["10th"].map('{:,.2f}'.format)
math_scores_by_grade["11th"] = math_scores_by_grade["11th"].map('{:,.2f}'.format)
math_scores_by_grade["12th"] = math_scores_by_grade["12th"].map('{:,.2f}'.format)
math_scores_by_grade
# Out:
#                          9th   10th   11th   12th
# school_name
# Bailey High School     77.08  77.00  77.52  76.49
# Cabrera High School    83.09  83.15  82.77  83.28
# Figueroa High School   76.40  76.54  76.88  77.15
# Ford High School       77.36  77.67  76.92  76.18
# Griffin High School    82.04  84.23  83.84  83.36
# Hernandez High School  77.44  77.34  77.14  77.19
# Holden High School     83.79  83.43  85.00  82.86
# Huang High School      77.03  75.91  76.45  77.23
# Johnson High School    77.19  76.69  77.49  76.86
# Pena High School       83.63  83.37  84.33  84.12
# Rodriguez High School  76.86  76.61  76.40  77.69
# Shelton High School    83.42  82.92  83.38  83.78
# Thomas High School     83.59  83.09  83.50  83.50
# Wilson High School     83.09  83.72  83.20  83.04
# Wright High School     83.26  84.01  83.84  83.64

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
# Create a pandas series for each grade. Hint: use a conditional statement.
grade_9 = school_data_complete.loc[school_data_complete["grade"] == "9th"]
grade_10 = school_data_complete.loc[school_data_complete["grade"] == "10th"]
grade_11 = school_data_complete.loc[school_data_complete["grade"] == "11th"]
grade_12 = school_data_complete.loc[school_data_complete["grade"] == "12th"]

# Group each series by school
schools_grade_9 = grade_9.groupby(["school_name"]).mean()
schools_grade_10 = grade_10.groupby(["school_name"]).mean()
schools_grade_11 = grade_11.groupby(["school_name"]).mean()
schools_grade_12 = grade_12.groupby(["school_name"]).mean()

# Combine the series into a dataframe
reading_scores_by_grade = pd.DataFrame({"9th":schools_grade_9["reading_score"],
                                     "10th":schools_grade_10["reading_score"],
                                     "11th":schools_grade_11["reading_score"],
                                     "12th":schools_grade_12["reading_score"]})

# Optional: give the displayed data cleaner formatting
reading_scores_by_grade["9th"] = reading_scores_by_grade["9th"].map('{:,.2f}'.format)
reading_scores_by_grade["10th"] = reading_scores_by_grade["10th"].map('{:,.2f}'.format)
reading_scores_by_grade["11th"] = reading_scores_by_grade["11th"].map('{:,.2f}'.format)
reading_scores_by_grade["12th"] = reading_scores_by_grade["12th"].map('{:,.2f}'.format)
reading_scores_by_grade
# Out:
#                          9th   10th   11th   12th
# school_name
# Bailey High School     81.30  80.91  80.95  80.91
# Cabrera High School    83.68  84.25  83.79  84.29
# Figueroa High School   81.20  81.41  80.64  81.38
# Ford High School       80.63  81.26  80.40  80.66
# Griffin High School    83.37  83.71  84.29  84.01
# Hernandez High School  80.87  80.66  81.40  80.86
# Holden High School     83.68  83.32  83.82  84.70
# Huang High School      81.29  81.51  81.42  80.31
# Johnson High School    81.26  80.77  80.62  81.23
# Pena High School       83.81  83.61  84.34  84.59
# Rodriguez High School  80.99  80.63  80.86  80.38
# Shelton High School    84.12  83.44  84.37  82.78
# Thomas High School     83.73  84.25  83.59  83.83
# Wilson High School     83.94  84.02  83.76  84.32
# Wright High School     83.83  83.81  84.16  84.07

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
